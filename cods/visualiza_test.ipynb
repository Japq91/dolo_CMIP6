# %%
import xarray as xr

# %%
d=xr.open_dataset('../data/TaiESM1/tas_day_TaiESM1_ssp126_r1i1p1f1_gn_201501_v2.0.nc')['tas']

# %%
d.mean('time').plot(robust=True,cmap='turbo',levels=11,extend='both')
#(d[0]*24*60*60).plot(robust=True,cmap='turbo',levels=11,extend='both')

# %%
d1=xr.open_dataset('pr_day_ACCESS-CM2_historical_r1i1p1f1_gn_2014.nc')['pr']

# %%
(d1[0]*24*60*60).plot(robust=True,cmap='turbo',levels=11,extend='both')
